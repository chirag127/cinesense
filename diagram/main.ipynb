# %%
# %pip install diagrams

# %%
""" Here is the explanation for the code above:
1. We are importing all the necessary libraries for the project.
2. We are importing the dataset and converting it into a dataframe.
3. We are splitting the dataset into train and test data.
4. We are fitting the training data into the model.
5. We are predicting the test data.
6. We are calculating the accuracy score for the test data.
7. We are fitting the entire dataset into the model.
8. We are calculating the accuracy score for the test data.
9. We are saving the model as a pickle file. """


# make a diagram to show the flow of the project
from diagrams import Diagram, Cluster, Edge
from diagrams.digitalocean.compute import Droplet
from diagrams.digitalocean.database import DbaasPrimary
from diagrams.elastic.elasticsearch import Logstash

# show the component that show the libraries used in the project
# import pandas as pd
# import numpy as np
# import nltk
# from nltk.corpus import stopwords
# from sklearn.feature_extraction.text import TfidfVectorizer
# from sklearn.model_selection import train_test_split
# from sklearn import naive_bayes
# from sklearn.metrics import roc_auc_score,accuracy_score
# import pickle
with Diagram("Libraries used in the project", show=False):
    with Cluster("Libraries"):
        Droplet1 = Droplet("Pandas")
        Droplet2 = Droplet("Numpy")
        Droplet3 = Droplet("Nltk")
        Droplet4 = Droplet("Sklearn")
        Droplet5 = Droplet("Pickle")


# show the component that show the dataset used in the project
# dataset = pd.read_csv('reviews.txt',sep = '\t', names =['Reviews','Comments'])
with Diagram("Dataset used in the project", show=False):
    with Cluster("Dataset"):
        Droplet6 = Droplet("Reviews.txt")
        Droplet7 = Droplet("Comments.txt")

# show the component that show the preprocessing process
# stop_words = set(stopwords.words('english'))
# vectorizer = TfidfVectorizer(use_idf=True, lowercase=True, strip_accents='ascii', stop_words=stop_words)

with Diagram("Preprocessing process", show=False):
    with Cluster("Preprocessing"):
        Droplet8 = Droplet("Stopwords")
        Droplet9 = Droplet("TfidfVectorizer")

# show the model component with logstash
with Diagram("Model", show=False):
    with Cluster("Model"):
        
        Droplet11 = Logstash("model")


[Droplet1, Droplet2, Droplet3, Droplet4, Droplet5] >> Droplet11
[Droplet1, Droplet2, Droplet3, Droplet4, Droplet5] >> Droplet8 >> Droplet9 >> Droplet11
[Droplet6, Droplet7] >> Droplet11
[Droplet6, Droplet7] >> Droplet8 >> Droplet9 >> Droplet11
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/.python/current/lib/python3.10/site-packages/graphviz/backend/execute.py:81, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      80     else:
# ---> 81         proc = subprocess.run(cmd, **kwargs)
#      82 except OSError as e:
#
# File ~/.python/current/lib/python3.10/subprocess.py:501, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     499     kwargs['stderr'] = PIPE
# --> 501 with Popen(*popenargs, **kwargs) as process:
#     502     try:
#
# File ~/.python/current/lib/python3.10/subprocess.py:966, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize)
# ...
